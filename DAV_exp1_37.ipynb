# %% [markdown]
# Prerna Ladkani
#
# roll:34     sub:DAV

# %% [markdown]
# Experiment 1

# %% [markdown]
# Aim: Getting introduced to data analytics libraries in Python and R

# %% [markdown]
# Lab Objectives: To effectively use libraries for data analytics.
#
#
# Lab Outcomes (LO): Explore various data analytics Libraries in R and Python. (LO1)

# %% [markdown]
# Task to be performed :
#
# 1.)Explore Top-5 Data Analytics Libraries in Python (w.r.t Features &
# Applications)
#
# 2.)Explore Top-5 Data Analytics Libraries in R (w.r.t Features & Applications)
#
# 3.)Install 2 Libraries each for Python and R
#
# 4.)Perform simple experiments on the 2 identified libraries each for Python and R
#
# 5.)Prepare a document with the Aim, Tasks performed, Program, Output, and Conclusion.

# %%
#TensorFlow
import tensorflow as tf
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.3037 - accuracy: 0.9124
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1466 - accuracy: 0.9568
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1105 - accuracy: 0.9655
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0899 - accuracy: 0.9726
# Epoch 5/5
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0730 - accuracy: 0.9778
# [0.07301146537065506, 0.9778000116348267]

# %%
#numpy
# The standard way to import NumPy:
import numpy as np

# Create a 2-D array, set every second element in
# some rows and find max per row:

x = np.arange(15, dtype=np.int64).reshape(3, 5)
x[1:, ::2] = -99
x
# array([[  0,   1,   2,   3,   4],
#        [-99,   6, -99,   8, -99],
#        [-99,  11, -99,  13, -99]])

x.max(axis=1)
# array([ 4,  8, 13])

# Generate normally distributed random numbers:
rng = np.random.default_rng()
samples = rng.normal(size=2500)
samples
# Out:
# array([-0.6475613 , -1.40181879, -0.47544966, ...,  0.31741792,
#        -1.44551692,  0.93164176])

# %%
#SciPy


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 3, 5, 4, 5])

# Perform linear regression using linregress from SciPy
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Print the regression results
print("Slope:", slope)
print("Intercept:", intercept)
print("R-squared:", r_value**2)

# Plot the original data and the regression line
plt.scatter(x, y, label='Original Data')
plt.plot(x, slope * x + intercept, color='red', label='Regression Line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression using SciPy')
plt.legend()
plt.show()
# Out:
# Slope: 0.7000000000000001
# Intercept: 1.6999999999999997
# R-squared: 0.7205882352941178

# %%
#Pandas
import pandas as pd


# reading the database
data = pd.read_csv("tips.csv")

# printing the top 10 rows
display(data.head(10))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
#keras
# Import necessary libraries
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Sample data for binary classification
X = [[0, 0], [0, 1], [1, 0], [1, 1]]
y = [0, 1, 1, 0]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Build a simple neural network model
model = Sequential()
model.add(Dense(4, input_dim=2, activation='relu'))  # Input layer with 4 neurons and ReLU activation
model.add(Dense(1, activation='sigmoid'))  # Output layer with 1 neuron and Sigmoid activation

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on the training data
model.fit(X_train, y_train, epochs=50, batch_size=2, verbose=1)

# Make predictions on the test data
predictions = model.predict(X_test)
rounded_predictions = [round(pred[0]) for pred in predictions]

# Evaluate the model
accuracy = accuracy_score(y_test, rounded_predictions)
print(f"Accuracy on test data: {accuracy*100:.2f}%")
# Out:
# Epoch 1/50
# 2/2 [==============================] - 2s 13ms/step - loss: 0.6568 - accuracy: 0.6667
# Epoch 2/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6555 - accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6536 - accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6523 - accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6512 - accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6495 - accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6486 - accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6472 - accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6458 - accuracy: 1.0000
# Epoch 10/50
# ...

# %%
#R
# Install and load the dplyr package
# install.packages("dplyr")
library(dplyr)

# Create a sample data frame
data <- data.frame(
  ID = c(1, 2, 3, 4, 5),
  Name = c("Alice", "Bob", "Charlie", "David", "Eve"),
  Age = c(25, 30, 22, 28, 35),
  Score = c(85, 90, 78, 92, 88)
)

# Display the original data
cat("Original Data:\n")
print(data)

# Use dplyr functions for data manipulation
data_filtered <- filter(data, Age > 25)
data_selected <- select(data, ID, Name)
data_arranged <- arrange(data, desc(Score))
data_mutated <- mutate(data, Grade = ifelse(Score >= 90, "A", "B"))
data_summarized <- summarise(data, Avg_Score = mean(Score))

# Display the manipulated data
cat("\nFiltered Data (Age > 25):\n")
print(data_filtered)

cat("\nSelected Data (ID, Name):\n")
print(data_selected)

cat("\nArranged Data (Descending by Score):\n")
print(data_arranged)

cat("\nMutated Data (Added Grade column):\n")
print(data_mutated)

cat("\nSummarized Data (Average Score):\n")
print(data_summarized)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# Original Data:
#   ID    Name Age Score
# 1  1   Alice  25    85
# 2  2     Bob  30    90
# 3  3 Charlie  22    78
# 4  4   David  28    92
# 5  5     Eve  35    88
#
# Filtered Data (Age > 25):
#   ID  Name Age Score
# 1  2   Bob  30    90
# 2  4 David  28    92
# 3  5   Eve  35    88
#
# Selected Data (ID, Name):
#   ID    Name
# 1  1   Alice
# 2  2     Bob
# 3  3 Charlie
# 4  4   David
# 5  5     Eve
#
# Arranged Data (Descending by Score):
#   ID    Name Age Score
# 1  4   David  28    92
# 2  2     Bob  30    90
# 3  5     Eve  35    88
# 4  1   Alice  25    85
# 5  3 Charlie  22    78
#
# Mutated Data (Added Grade column):
#   ID    Name Age Score Grade
# 1  1   Alice  25    85     B
# 2  2     Bob  30    90     A
# 3  3 Charlie  22    78     B
# ...

# %%
#tidyr
# Install and load the tidyr package
# install.packages("tidyr")
library(tidyr)

# Create a simple data frame
data <- data.frame(
  ID = c(1, 2, 3),
  Name = c("John", "Jane", "Bob"),
  Math = c(90, NA, 75),
  English = c(85, 88, 92),
  History = c(78, 80, NA)
)

# Print the original data frame
print("Original Data Frame:")
print(data)

# Reshape the data using tidyr's gather function
tidy_data <- gather(data, key = "Subject", value = "Score", -ID, -Name)

# Print the tidied data
print("\nTidied Data:")
print(tidy_data)

# Spread the data back to the original wide format
spread_data <- spread(tidy_data, key = "Subject", value = "Score")

# Print the spread data
print("\nSpread Data:")
print(spread_data)
install.packages("tidyr")
# Out:
# [1] "Original Data Frame:"
#   ID Name Math English History
# 1  1 John   90      85      78
# 2  2 Jane   NA      88      80
# 3  3  Bob   75      92      NA
# [1] "\nTidied Data:"
#   ID Name Subject Score
# 1  1 John    Math    90
# 2  2 Jane    Math    NA
# 3  3  Bob    Math    75
# 4  1 John English    85
# 5  2 Jane English    88
# 6  3  Bob English    92
# 7  1 John History    78
# 8  2 Jane History    80
# 9  3  Bob History    NA
# [1] "\nSpread Data:"
#   ID Name English History Math
# 1  1 John      85      78   90
# 2  2 Jane      88      80   NA
# 3  3  Bob      92      NA   75
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#readr
install.packages("readr")
# Install and load the readr package
# install.packages("readr")
library(readr)

# Define the path to your CSV file
file_path <- "tips.csv"

# Read the CSV file using read_csv from readr
data <- read_csv(file_path)

# Display the first few rows of the data
print("First 5 rows of the data:")
print(head(data))

# Display basic information about the data
print("\nBasic information about the data:")
print(str(data))

# Display summary statistics of numeric columns
print("\nSummary statistics:")
print(summary(data))
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Rows: 244 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): sex, smoker, day, time
# dbl (3): total_bill, tip, size
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# [1] "First 5 rows of the data:"
# # A tibble: 6 × 7
#   total_bill   tip sex    smoker day   time    size
#        <dbl> <dbl> <chr>  <chr>  <chr> <chr>  <dbl>
# 1       17.0  1.01 Female No     Sun   Dinner     2
# 2       10.3  1.66 Male   No     Sun   Dinner     3
# 3       21.0  3.5  Male   No     Sun   Dinner     3
# 4       23.7  3.31 Male   No     Sun   Dinner     2
# 5       24.6  3.61 Female No     Sun   Dinner     4
# 6       25.3  4.71 Male   No     Sun   Dinner     4
# [1] "\nBasic information about the data:"
# ...

# %%
install.packages("stringr")
# Install and load the stringr package
# install.packages("stringr")
library(stringr)

# Example string
text <- "Hello, World! This is a simple example."

# Extract all words from the text
words <- str_extract_all(text, "\\w+")

# Convert the list of words to a single character vector
all_words <- unlist(words)

# Print the original text and extracted words
cat("Original Text:", text, "\n")
cat("Extracted Words:", paste(all_words, collapse = " "), "\n")

# Count the number of words in the text
word_count <- length(all_words)
cat("Number of Words:", word_count, "\n")

# Replace "World" with "Universe" in the text
modified_text <- str_replace(text, "World", "Universe")
cat("Modified Text:", modified_text, "\n")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# Original Text: Hello, World! This is a simple example.
# Extracted Words: Hello World This is a simple example
# Number of Words: 7
# Modified Text: Hello, Universe! This is a simple example.

# %%
#ggplot2

install.packages("ggplot2")
# Install and load the ggplot2 package
# install.packages("ggplot2")
library(ggplot2)

# Sample data
data <- data.frame(
  X = c(1, 2, 3, 4, 5),
  Y = c(2, 3, 5, 4, 5)
)

# Create a scatter plot using ggplot2
ggplot(data, aes(x = X, y = Y)) +
  geom_point(color = "blue") +
  labs(title = "Scatter Plot using ggplot2",
       x = "X-axis Label",
       y = "Y-axis Label")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# plot without title

# %% [markdown]
# Conclusion : Thus we have been successfully introduced to Python and R libraries
